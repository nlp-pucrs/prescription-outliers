# %%
# %matplotlib inline
import sys
import outliers
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.ensemble import IsolationForest
from sklearn.preprocessing import normalize
from sklearn.metrics import f1_score
import numpy as np

import warnings
warnings.filterwarnings('ignore')

# %%
medications = outliers.getOverdoseMedications()
medications.shape
# Out:
# (118,)

# %%
regression_data = pd.DataFrame()

for med in np.asarray(medications):

    X, Y = outliers.getPrescriptions(med)
    X_norm = normalize(X,norm='l2')
    print(med + ': ',len(X))

    if len(X) < 100: 
        continue
    
    ep_range = np.arange(0.01,1.0,0.03)
    f_scores = {}
    
    for epsilon in ep_range:
        clf = IsolationForest(contamination=epsilon)
        clf.fit(X_norm)
        y_pred = clf.predict(X_norm)

        params = clf.get_params()
        
        y_pred[y_pred == 1] = 0
        y_pred[y_pred == -1] = 1

        f = f1_score(y_pred, Y)
        ep = epsilon.mean()

        f_scores[ep] = f
        
        #sys.stdout.write(str(ep) + '='+ str(round(f,2)) +', ')
        #break
    
    data_stats = []

    data_stats.append( np.mean(X_norm) ) # 0
    data_stats.append( np.std(X_norm) ) # 1
    data_stats.append( np.median(X_norm) ) # 2
    data_stats.append( np.percentile(X_norm,50) ) # 3
    data_stats.append( np.percentile(X_norm,70) ) # 4
    
    epsilon = max(f_scores, key=f_scores.get) 
    print(epsilon, f_scores[epsilon])
    
    data_stats.append( epsilon )
    
    reshape_data = pd.DataFrame( np.reshape(np.asarray(data_stats), (1,len(data_stats))  ) )
    regression_data = regression_data.append( reshape_data )
    
    #break
    
regression_data.shape
# Out:
# ABACAVIR 300 mg CP:  861
# 0.01 0.965517241379
# ACETAZOLAMIDA 250 mg CP:  120
# 0.13 0.342857142857
# ACICLOVIR 200 mg CP:  1470
# 0.01 0.666666666667
# ACIDO FOLICO 5 mg CP:  1937
# 0.31 0.00720164609053
# AMICACINA 500 mg/2 ml SOL INJ:  492
# 0.19 0.536231884058
# AMIODARONA 200 mg CP:  448
# 0.01 0.833333333333
# AMOXICILINA + CLAVULANATO 1 g + 200 mg SOL INJ:  2403
# 0.07 0.263959390863
# AMOXICILINA + CLAVULANATO 500 mg + 125 mg CP:  963
# 0.04 0.5
# AMOXICILINA 500 mg CP:  103
# 0.31 0.842105263158
# AMPICILINA + SULBACTAM 2 g + 1 g SOL INJ:  1802
# 0.04 0.542168674699
# AMPICILINA 500 mg CP:  90
# ANLODIPINO 10 mg CP:  4775
# 0.01 0.820895522388
# ANLODIPINO 5 mg CP:  2874
# 0.01 0.535714285714
# ATORVASTATINA 80 mg CP:  3474
# 0.01 0.288770053476
# AZITROMICINA 500 mg CP:  416
# 0.31 0.00479616306954
# AZITROMICINA 500 mg SOL INJ:  726
# 0.13 0.0388349514563
# BICARBONATO DE SODIO 10 g PO:  26
# BISACODIL 5 mg CP:  3145
# 0.61 0.000635727908455
# CARVEDILOL 6,25 mg CP:  463
# 0.01 0.923076923077
# CEFUROXIMA 250 mg CP:  167
# 0.1 0.444444444444
# CETOPROFENO 100 mg SOL INJ IV:  2013
# 0.07 0.0346820809249
# CIANOCOBALAMINA ( VIT B12 ) 5.000 mcg/2 ml SOL INJ:  223
# 0.13 0.0425531914894
# CIPROFLOXACINA 200 mg/100 ml SOL INJ SISTEMA FECHADO:  274
# 0.13 0.618181818182
# CIPROFLOXACINA 500 mg CP:  1063
# 0.1 0.0157480314961
# CLINDAMICINA 300 mg CP:  268
# 0.25 0.697247706422
# CLONAZEPAM 2 mg CP:  2197
# 0.04 0.417582417582
# CLONAZEPAM 2,5 mg/ml SOL ORAL - com conta-gotas acoplado na tampa do frasco ou na embalagem do medicamento:  151
# 0.46 0.0888888888889
# CLONIDINA 0,150 mg CP:  3932
# 0.01 0.592592592593
# CLORETO DE POTASSIO 6 % (0,8 mEq/ml) SOL AQ C/ADOCANTE ARTIFICIAL - FR. 100 A 200 ml:  1541
# 0.1 0.429906542056
# CLORETO DE SODIO 0,9 % SOL INJ 1000 ml:  464
# 0.94 0.884615384615
# CLORETO DE SODIO 0,9 % SOL INJ 1000 ml SISTEMA FECHADO:  11
# CLORETO DE SODIO 0,9 % SOL INJ 250 ml:  493
# 0.76 0.911699779249
# CLORETO DE SODIO 0,9 % SOL INJ 250 ml SISTEMA FECHADO:  2
# CLORETO DE SODIO 0,9 % SOL INJ 500 ml:  2803
# 0.94 0.783684096333
# CLORETO DE SODIO 0,9 % SOL INJ 500 ml SISTEMA FECHADO:  4
# CLORETO DE SODIO 10% 10ml SOL INJ:  5
# CLORETO DE SODIO 20 % ( 3,42 mEq/ml ) 20 ml SOL INJ:  52
# CLOZAPINA 100 mg CP:  160
# 0.76 0.0487804878049
# CODEINA 30 mg CP:  4950
# 0.01 0.0289855072464
# DEXAMETASONA 4 mg CP:  659
# 0.04 0.137931034483
# DIAZEPAM 10 mg/2 ml SOL INJ:  170
# 0.01 1.0
# DICLOFENACO 75 mg/3 ml SOL INJ:  25
# DIGOXINA 0,25 mg CP:  1174
# 0.13 0.810996563574
# DIPIRONA 1 g/2 ml SOL INJ:  43054
# 0.01 0.495774647887
# DIPIRONA 500 mg/ml SOL ORAL - com conta-gotas acoplado na tampa do frasco ou na embalagem do medicamento:  7018
# 0.04 0.740331491713
# DOXAZOSINA 2 mg CP:  1875
# 0.01 0.212765957447
# DOXICICLINA 100 mg CP:  103
# 0.1 0.736842105263
# DROPERIDOL 2,5 mg/ml SOL INJ:  1082
# 0.04 0.806201550388
# ENALAPRIL 10 mg CP:  4366
# 0.13 0.029197080292
# ENALAPRIL 20 mg CP:  2602
# 0.07 0.348936170213
# ENALAPRIL 5 mg CP:  2332
# 0.1 0.041958041958
# ENOXAPARINA 60 mg/0,6 ml - SERINGA GRADUADA PRE-PREENCHIDA:  1686
# 0.1 0.3125
# ENOXAPARINA 80 mg/0,8 ml - SERINGA GRADUADA PRE-PREENCHIDA:  1126
# 0.04 0.776470588235
# ERITROMICINA 50 mg/ml SUSP ORAL:  4
# FENITOINA 250 mg/5 ml SOL INJ:  620
# 0.22 0.25
# FENOBARBITAL 100 mg CP:  918
# 0.01 1.0
# FENOBARBITAL 40 mg/ml SOL ORAL - com conta-gotas acoplado na tampa do frasco ou na embalagem do medicamento:  44
# FERRO COLOIDAL 100 mg/ 5 ml SOL INJ IV:  115
# 0.07 1.0
# FLUORHIDROCORTISONA 0,1 mg CP:  131
# 0.07 0.526315789474
# FLUOXETINA 20 mg CP:  3891
# 0.04 0.105769230769
# FUROSEMIDA 40 mg CP:  5610
# 0.04 0.02416918429
# GLICERINA 12% SOL RETAL 500 ml C/ SONDA - SISTEMA FECHADO:  75
# GLUCONATO DE CALCIO 10 % (0,465 mEq/ml) 10 ml SOL INJ:  522
# 0.01 0.4
# HEPARINA 5.000 UI/0,25 ml SOL INJ:  38553
# 0.25 0.000207296849088
# HIDRALAZINA 50 mg CP:  1739
# 0.46 0.215854823305
# HIDROCLOROTIAZIDA 50 mg CP:  283
# 0.04 0.444444444444
# HIDROXIDO DE ALUMINIO 6 % SUSP ORAL FRASCO DE 100ml A 240ml:  236
# 0.61 0.894613583138
# HIDROXIDO DE MAGNESIO 8 % SUSP ORAL:  662
# 0.61 0.561505065123
# HIOSCINA (BUTILBROMETO DE ESCOPOLAMINA) 20 mg/ml SOL INJ:  4088
# 0.04 0.771014492754
# HIOSCINA + DIPIRONA 20 mg + 2,5 g / 5 ml SOL INJ:  132
# 0.31 0.95652173913
# IMIPRAMINA 25 mg CP:  122
# 0.76 1.0
# ISOSSORBIDA MONONITRATO 40 mg CP:  1623
# 0.13 0.220183486239
# L-TIROXINA 100 mcg CP:  207
# 0.07 1.0
# L-TIROXINA 25 mcg CP:  244
# 0.07 1.0
# LACTULOSE 667 mg/ml SOL ORAL:  9877
# 0.01 0.156862745098
# LAMIVUDINA 10 mg/ml SOL ORAL:  184
# 0.01 1.0
# LAMIVUDINA 150 mg CP:  1217
# 0.31 0.0885245901639
# LITIO CARBONATO 300 mg CP:  767
# 0.04 0.509090909091
# LOPERAMIDA 2 mg CP:  1307
# 0.13 0.0796019900498
# LOPINAVIR + RITONAVIR 200 mg + 50 mg CP:  311
# 0.07 0.85
# LOPINAVIR + RITONAVIR 80 mg + 20 mg SOL ORAL:  110
# 0.31 1.0
# LOSARTAN 50 mg CP:  4395
# 0.04 0.0782918149466
# MANITOL 20 % SOL INJ 250 ml:  10
# MANITOL 20 % SOL INJ 250 ml SISTEMA FECHADO:  56
# METOPROLOL SUCCINATO 25 mg CP:  1339
# 0.07 0.0618556701031
# METOPROLOL SUCCINATO 50 mg CP:  2174
# 0.31 0.0236363636364
# METRONIDAZOL 40 mg/ml SUSP ORAL:  50
# METRONIDAZOL 500 mg / 100 ml SOL INJ SISTEMA FECHADO:  1728
# 0.01 0.848484848485
# MIDAZOLAM 15 mg CP:  54
# MISOPROSTOL 200 mcg CP:  8
# MORFINA 10 mg/ml SOL INJ:  18591
# 0.01 0.0103626943005
# MORFINA 10 mg/ml SOL ORAL - com conta-gotas acoplado na tampa do frasco ou na embalagem do medicamento:  1781
# 0.34 0.49358974359
# MORFINA 30 mg CP - comprimidos embalados unitariamente:  24
# N-ACETIL-L-CISTEINA 600 mg PO:  20
# OCITOCINA 5 UI/ml SOL INJ:  9
# OCTREOTIDA 0,5 mg/ml SOL INJ:  3
# OLEO MINERAL LIQ 100 ml:  3112
# 0.13 0.0554744525547
# OMEPRAZOL 40mg SOL INJ IV DIRETO EM EMBALAGEM INDIVIDUAL COM FR/AMP + DILUENTE (EM EMBALAGEM CONJUNTA):  5677
# 0.31 0.00197726149283
# ONDANSETRONA 8 mg/4 ml SOL INJ IV:  6743
# 0.31 0.985656176408
# OSELTAMIVIR 75 mg CP:  120
# 0.01 0.222222222222
# PARACETAMOL + CODEINA ( 500 mg + 30 mg ) CP:  5797
# 0.01 0.333333333333
# PARACETAMOL 500 mg CP:  19161
# 0.01 0.0438871473354
# PETIDINA (MEPERIDINA) 100 mg/ 2 ml SOL INJ:  53
# PIPERACILINA + TAZOBACTAM 4 g + 500 mg SOL INJ:  7979
# 0.01 0.206349206349
# PREDNISONA 20 mg CP:  4626
# 0.07 0.615984405458
# PROMETAZINA 50 mg/2 ml SOL INJ:  489
# 0.31 0.590717299578
# PROSTAGLANDINA E1 20 mcg SOL INJ:  22
# RIFAMPICINA 300 mg CP:  231
# 0.01 0.133333333333
# RISPERIDONA 2 mg CP:  1701
# 0.07 0.131736526946
# SALBUTAMOL 100 mcg/jato AEROSSOL ORAL:  73
# SULFAMETOXAZOL + TRIMETOPRIMA 800 mg + 160 mg CP:  2898
# 0.1 0.246073298429
# SULFATO DE MAGNESIO 10% 10 ml:  274
# 0.04 0.727272727273
# SULFATO DE MAGNESIO 50 % (4,2 mEq/ml) 10 ml:  1229
# 0.04 0.117647058824
# TIGECICLINA 50 mg SOL INJ:  80
# TRAMADOL 50mg/ml 1ml SOL INJ:  3607
# 0.76 0.007732670533
# TRETINOINA 10 mg CP:  122
# 0.01 1.0
# VANCOMICINA 500 mg/ 100 ml SOL INJ SISTEMA FECHADO:  1028
# 0.31 0.159340659341
# VARFARINA 5 mg CP:  1751
# 0.04 0.555555555556
# (94, 6)

# %%
from sklearn.svm import SVR, LinearSVR
from sklearn.model_selection import GridSearchCV, cross_val_score

data = regression_data.drop(5,1).values
target = regression_data[5].values

C_range = [2 ** i for i in range(-7, 7, 1)]
parameters = {'kernel':['linear','rbf'], 'C':C_range}
grid_search = GridSearchCV(SVR(), parameters, cv=5, n_jobs=3, verbose=1, scoring='neg_mean_absolute_error')
grid_search.fit(data, target)
print(grid_search.best_estimator_)
print(grid_search.best_score_)
print(grid_search.best_params_)
# Out:
# Fitting 5 folds for each of 28 candidates, totalling 140 fits
# SVR(C=2, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='linear', max_iter=-1, shrinking=True, tol=0.001, verbose=False)
# -0.147906998284
# {'C': 2, 'kernel': 'linear'}
# [Parallel(n_jobs=3)]: Done 140 out of 140 | elapsed:    0.1s finished

# %%
from sklearn.linear_model import Ridge, LinearRegression, LogisticRegression, Lasso, BayesianRidge, LassoLars

scores = cross_val_score(LinearSVR(), data, target, scoring='neg_mean_absolute_error')
print(scores.mean())
scores = cross_val_score(Ridge(), data, target, scoring='neg_mean_absolute_error')
print(scores.mean())
scores = cross_val_score(LinearRegression(), data, target, scoring='neg_mean_absolute_error')
print(scores.mean())
scores = cross_val_score(Lasso(), data, target, scoring='neg_mean_absolute_error')
print(scores.mean())
scores = cross_val_score(BayesianRidge(), data, target, scoring='neg_mean_absolute_error')
print(scores.mean())
scores = cross_val_score(LassoLars(), data, target, scoring='neg_mean_absolute_error')
print(scores.mean())
# Out:
# -0.142918522055
# -0.165534138574
# -0.169595810953
# -0.16639608935
# -0.166385956913
# -0.16639608935

# %%
parameters = {'C':np.arange(0.01,2,0.01)}
grid_search = GridSearchCV(LinearSVR(), parameters, cv=5, n_jobs=3, verbose=1, scoring='neg_mean_absolute_error')
data_less = regression_data[[0]].values
grid_search.fit(data_less, target)
print(grid_search.best_estimator_)
print(grid_search.best_score_)
print(grid_search.best_params_)
# Out:
# Fitting 5 folds for each of 199 candidates, totalling 995 fits
# LinearSVR(C=0.14000000000000001, dual=True, epsilon=0.0, fit_intercept=True,
#      intercept_scaling=1.0, loss='epsilon_insensitive', max_iter=1000,
#      random_state=None, tol=0.0001, verbose=0)
# -0.139533192613
# {'C': 0.14000000000000001}
# [Parallel(n_jobs=3)]: Done 995 out of 995 | elapsed:    0.5s finished

# %%
regr = LinearSVR(C=0.01)
regr.fit(data_less, target)
print(regr.coef_)
print(regr.intercept_)
# Out:
# [ 0.02312557]
# [ 0.05791566]

# %%
predicted_ep = regr.predict(data_less)

# %%
idx = 0
best_scores = []
predicted_scores = []
for med in np.asarray(medications):

    X, Y = outliers.getPrescriptions(med)
    X_norm = normalize(X,norm='l2')

    if len(X) < 100: 
        continue
    
    clf = IsolationForest(contamination=target[idx])
    clf.fit(X_norm)
    y_pred = clf.predict(X_norm)
    y_pred[y_pred == 1] = 0
    y_pred[y_pred == -1] = 1
    f = f1_score(y_pred, Y)
    best_scores.append(f)
    
    clf = IsolationForest(contamination=predicted_ep[idx])
    clf.fit(X_norm)
    y_pred = clf.predict(X_norm)
    y_pred[y_pred == 1] = 0
    y_pred[y_pred == -1] = 1
    f = f1_score(y_pred, Y)
    predicted_scores.append(f)
    
    print(med + ': Best:', 
          target[idx], 
          best_scores[idx], 
          ', Predicted: ',
          predicted_ep[idx],
          predicted_scores[idx])
    
    idx += 1
    
    #break
# Out:
# ABACAVIR 300 mg CP: Best: 0.01 0.965517241379 , Predicted:  0.0695156306417 0.0986842105263
# ACETAZOLAMIDA 250 mg CP: Best: 0.13 0.342857142857 , Predicted:  0.0698660850603 0.0
# ACICLOVIR 200 mg CP: Best: 0.01 0.666666666667 , Predicted:  0.0696437443944 0.145161290323
# ACIDO FOLICO 5 mg CP: Best: 0.31 0.00720164609053 , Predicted:  0.0715207016888 0.00720164609053
# AMICACINA 500 mg/2 ml SOL INJ: Best: 0.19 0.536231884058 , Predicted:  0.0695083454615 0.166666666667
# AMIODARONA 200 mg CP: Best: 0.01 0.833333333333 , Predicted:  0.0695760857401 0.135135135135
# AMOXICILINA + CLAVULANATO 1 g + 200 mg SOL INJ: Best: 0.07 0.263959390863 , Predicted:  0.0696466821998 0.263959390863
# AMOXICILINA + CLAVULANATO 500 mg + 125 mg CP: Best: 0.04 0.5 , Predicted:  0.0695338723292 0.320987654321
# AMOXICILINA 500 mg CP: Best: 0.31 0.842105263158 , Predicted:  0.069817611634 0.0
# AMPICILINA + SULBACTAM 2 g + 1 g SOL INJ: Best: 0.04 0.542168674699 , Predicted:  0.0739806597376 0.371900826446
# ANLODIPINO 10 mg CP: Best: 0.01 0.820895522388 , Predicted:  0.0705916537057 0.0240016552866
# ANLODIPINO 5 mg CP: Best: 0.01 0.535714285714 , Predicted:  0.071735803658 0.110701107011
# ATORVASTATINA 80 mg CP: Best: 0.01 0.288770053476 , Predicted:  0.0696291433379 0.0154241645244
# AZITROMICINA 500 mg CP: Best: 0.31 0.00479616306954 , Predicted:  0.069531924744 0.00479616306954
# AZITROMICINA 500 mg SOL INJ: Best: 0.13 0.0388349514563 , Predicted:  0.0701320237997 0.0388349514563
# BISACODIL 5 mg CP: Best: 0.61 0.000635727908455 , Predicted:  0.0720274283277 0.0
# CARVEDILOL 6,25 mg CP: Best: 0.01 0.923076923077 , Predicted:  0.0724757810703 0.452830188679
# CEFUROXIMA 250 mg CP: Best: 0.1 0.444444444444 , Predicted:  0.0695328847769 0.205128205128
# CETOPROFENO 100 mg SOL INJ IV: Best: 0.07 0.0346820809249 , Predicted:  0.0697445106176 0.0346820809249
# CIANOCOBALAMINA ( VIT B12 ) 5.000 mcg/2 ml SOL INJ: Best: 0.13 0.0425531914894 , Predicted:  0.0703797581752 0.0425531914894
# CIPROFLOXACINA 200 mg/100 ml SOL INJ SISTEMA FECHADO: Best: 0.13 0.618181818182 , Predicted:  0.0698259914685 0.0
# CIPROFLOXACINA 500 mg CP: Best: 0.1 0.0157480314961 , Predicted:  0.0695264191549 0.0157480314961
# CLINDAMICINA 300 mg CP: Best: 0.25 0.697247706422 , Predicted:  0.0695436493024 0.0
# CLONAZEPAM 2 mg CP: Best: 0.04 0.417582417582 , Predicted:  0.0737245233129 0.063122923588
# CLONAZEPAM 2,5 mg/ml SOL ORAL - com conta-gotas acoplado na tampa do frasco ou na embalagem do medicamento: Best: 0.46 0.0888888888889 , Predicted:  0.0713149494251 0.0
# CLONIDINA 0,150 mg CP: Best: 0.01 0.592592592593 , Predicted:  0.0699484986333 0.144578313253
# CLORETO DE POTASSIO 6 % (0,8 mEq/ml) SOL AQ C/ADOCANTE ARTIFICIAL - FR. 100 A 200 ml: Best: 0.1 0.429906542056 , Predicted:  0.0711685903635 0.429906542056
# CLORETO DE SODIO 0,9 % SOL INJ 1000 ml: Best: 0.94 0.884615384615 , Predicted:  0.0703505155999 0.0677966101695
# CLORETO DE SODIO 0,9 % SOL INJ 250 ml: Best: 0.76 0.911699779249 , Predicted:  0.069943125336 0.0
# CLORETO DE SODIO 0,9 % SOL INJ 500 ml: Best: 0.94 0.783684096333 , Predicted:  0.0708412369483 0.0986547085202
# CLOZAPINA 100 mg CP: Best: 0.76 0.0487804878049 , Predicted:  0.0695518863716 0.0
# CODEINA 30 mg CP: Best: 0.01 0.0289855072464 , Predicted:  0.0708913771893 0.00332225913621
# DEXAMETASONA 4 mg CP: Best: 0.04 0.137931034483 , Predicted:  0.0733515598828 0.0714285714286
# DIAZEPAM 10 mg/2 ml SOL INJ: Best: 0.01 1.0 , Predicted:  0.0714355594485 0.235294117647
# DIGOXINA 0,25 mg CP: Best: 0.13 0.810996563574 , Predicted:  0.0712983306966 0.328502415459
# DIPIRONA 1 g/2 ml SOL INJ: Best: 0.01 0.511627906977 , Predicted:  0.0695330341049 0.00851103196263
# DIPIRONA 500 mg/ml SOL ORAL - com conta-gotas acoplado na tampa do frasco ou na embalagem do medicamento: Best: 0.04 0.740331491713 , Predicted:  0.0707038544931 0.403587443946
# DOXAZOSINA 2 mg CP: Best: 0.01 0.212765957447 , Predicted:  0.0726370311039 0.0346020761246
# DOXICICLINA 100 mg CP: Best: 0.1 0.736842105263 , Predicted:  0.0699032200927 0.736842105263
# DROPERIDOL 2,5 mg/ml SOL INJ: Best: 0.04 0.806201550388 , Predicted:  0.0714629641347 0.679738562092
# ENALAPRIL 10 mg CP: Best: 0.13 0.029197080292 , Predicted:  0.071481095836 0.029197080292
# ENALAPRIL 20 mg CP: Best: 0.07 0.348936170213 , Predicted:  0.0705785614602 0.348936170213
# ENALAPRIL 5 mg CP: Best: 0.1 0.041958041958 , Predicted:  0.0728813892878 0.041958041958
# ENOXAPARINA 60 mg/0,6 ml - SERINGA GRADUADA PRE-PREENCHIDA: Best: 0.1 0.3125 , Predicted:  0.0698356177864 0.3125
# ENOXAPARINA 80 mg/0,8 ml - SERINGA GRADUADA PRE-PREENCHIDA: Best: 0.04 0.776470588235 , Predicted:  0.0697690364267 0.420382165605
# FENITOINA 250 mg/5 ml SOL INJ: Best: 0.22 0.25 , Predicted:  0.0697949778493 0.0597014925373
# FENOBARBITAL 100 mg CP: Best: 0.01 1.0 , Predicted:  0.0696278523703 0.37037037037
# FERRO COLOIDAL 100 mg/ 5 ml SOL INJ IV: Best: 0.07 1.0 , Predicted:  0.0695698702244 1.0
# FLUORHIDROCORTISONA 0,1 mg CP: Best: 0.07 0.526315789474 , Predicted:  0.0706131767183 0.526315789474
# FLUOXETINA 20 mg CP: Best: 0.04 0.105769230769 , Predicted:  0.0699954652237 0.0242825607064
# FUROSEMIDA 40 mg CP: Best: 0.04 0.0 , Predicted:  0.0699588196751 0.016632016632
# GLUCONATO DE CALCIO 10 % (0,465 mEq/ml) 10 ml SOL INJ: Best: 0.01 0.4 , Predicted:  0.070621213524 0.0114285714286
# HEPARINA 5.000 UI/0,25 ml SOL INJ: Best: 0.25 0.000207296849088 , Predicted:  0.0694918485133 0.000207296849088
# HIDRALAZINA 50 mg CP: Best: 0.46 0.215854823305 , Predicted:  0.0701999995363 0.0
# HIDROCLOROTIAZIDA 50 mg CP: Best: 0.04 0.444444444444 , Predicted:  0.0700778480194 0.285714285714
# HIDROXIDO DE ALUMINIO 6 % SUSP ORAL FRASCO DE 100ml A 240ml: Best: 0.61 0.894613583138 , Predicted:  0.072396643864 0.133333333333
# HIDROXIDO DE MAGNESIO 8 % SUSP ORAL: Best: 0.61 0.561505065123 , Predicted:  0.0706600730006 0.0540540540541
# HIOSCINA (BUTILBROMETO DE ESCOPOLAMINA) 20 mg/ml SOL INJ: Best: 0.04 0.771014492754 , Predicted:  0.0714351865368 0.336820083682
# HIOSCINA + DIPIRONA 20 mg + 2,5 g / 5 ml SOL INJ: Best: 0.31 0.95652173913 , Predicted:  0.06963085238 0.0729927007299
# IMIPRAMINA 25 mg CP: Best: 0.76 1.0 , Predicted:  0.0694966365552 0.394736842105
# ISOSSORBIDA MONONITRATO 40 mg CP: Best: 0.13 0.175609756098 , Predicted:  0.070436040321 0.175609756098
# L-TIROXINA 100 mcg CP: Best: 0.07 1.0 , Predicted:  0.0705741520864 1.0
# L-TIROXINA 25 mcg CP: Best: 0.07 1.0 , Predicted:  0.07 1.0
# LACTULOSE 667 mg/ml SOL ORAL: Best: 0.01 0.156862745098 , Predicted:  0.0708060847644 0.0663129973475
# LAMIVUDINA 10 mg/ml SOL ORAL: Best: 0.01 1.0 , Predicted:  0.0696545370668 0.103448275862
# LAMIVUDINA 150 mg CP: Best: 0.31 0.0885245901639 , Predicted:  0.0695671580872 0.0
# LITIO CARBONATO 300 mg CP: Best: 0.04 0.509090909091 , Predicted:  0.0695860655993 0.318181818182
# LOPERAMIDA 2 mg CP: Best: 0.13 0.0555555555556 , Predicted:  0.0739037269855 0.0796019900498
# LOPINAVIR + RITONAVIR 200 mg + 50 mg CP: Best: 0.07 0.85 , Predicted:  0.0695359576225 0.85
# LOPINAVIR + RITONAVIR 80 mg + 20 mg SOL ORAL: Best: 0.31 1.0 , Predicted:  0.0695251203711 1.0
# LOSARTAN 50 mg CP: Best: 0.04 0.0782918149466 , Predicted:  0.0698926092385 0.0552763819095
# METOPROLOL SUCCINATO 25 mg CP: Best: 0.07 0.0618556701031 , Predicted:  0.0699758147769 0.0618556701031
# METOPROLOL SUCCINATO 50 mg CP: Best: 0.31 0.0236363636364 , Predicted:  0.069709851289 0.0
# METRONIDAZOL 500 mg / 100 ml SOL INJ SISTEMA FECHADO: Best: 0.01 0.848484848485 , Predicted:  0.0695604133039 0.0296296296296
# MORFINA 10 mg/ml SOL INJ: Best: 0.01 0.0103626943005 , Predicted:  0.0737014336332 0.001246105919
# MORFINA 10 mg/ml SOL ORAL - com conta-gotas acoplado na tampa do frasco ou na embalagem do medicamento: Best: 0.34 0.441478439425 , Predicted:  0.0721762060955 0.0082304526749
# OLEO MINERAL LIQ 100 ml: Best: 0.13 0.0554744525547 , Predicted:  0.0707541377223 0.0554744525547
# OMEPRAZOL 40mg SOL INJ IV DIRETO EM EMBALAGEM INDIVIDUAL COM FR/AMP + DILUENTE (EM EMBALAGEM CONJUNTA): Best: 0.31 0.00197726149283 , Predicted:  0.0698645887831 0.00197726149283
# ONDANSETRONA 8 mg/4 ml SOL INJ IV: Best: 0.31 0.985656176408 , Predicted:  0.072998030505 0.985656176408
# OSELTAMIVIR 75 mg CP: Best: 0.01 0.222222222222 , Predicted:  0.0697725034293 0.0165289256198
# PARACETAMOL + CODEINA ( 500 mg + 30 mg ) CP: Best: 0.01 0.333333333333 , Predicted:  0.0720333227562 0.0670859538784
# PARACETAMOL 500 mg CP: Best: 0.01 0.0425531914894 , Predicted:  0.069559031659 0.00573445081606
# PIPERACILINA + TAZOBACTAM 4 g + 500 mg SOL INJ: Best: 0.01 0.206349206349 , Predicted:  0.0739970907649 0.036775106082
# PREDNISONA 20 mg CP: Best: 0.07 0.60510805501 , Predicted:  0.0699173311521 0.615984405458
# PROMETAZINA 50 mg/2 ml SOL INJ: Best: 0.31 0.590717299578 , Predicted:  0.0714263537151 0.127906976744
# RIFAMPICINA 300 mg CP: Best: 0.01 0.133333333333 , Predicted:  0.0695004823737 0.0454545454545
# RISPERIDONA 2 mg CP: Best: 0.07 0.127906976744 , Predicted:  0.0734494773535 0.127906976744
# SULFAMETOXAZOL + TRIMETOPRIMA 800 mg + 160 mg CP: Best: 0.1 0.246073298429 , Predicted:  0.0694921538074 0.246073298429
# SULFATO DE MAGNESIO 10% 10 ml: Best: 0.04 0.727272727273 , Predicted:  0.0698704024042 0.372093023256
# SULFATO DE MAGNESIO 50 % (4,2 mEq/ml) 10 ml: Best: 0.04 0.117647058824 , Predicted:  0.070651770482 0.0808080808081
# TRAMADOL 50mg/ml 1ml SOL INJ: Best: 0.76 0.007732670533 , Predicted:  0.0701482137357 0.0
# TRETINOINA 10 mg CP: Best: 0.01 1.0 , Predicted:  0.0697401625135 0.0909090909091
# VANCOMICINA 500 mg/ 100 ml SOL INJ SISTEMA FECHADO: Best: 0.31 0.159340659341 , Predicted:  0.0695019996235 0.0
# VARFARINA 5 mg CP: Best: 0.04 0.555555555556 , Predicted:  0.0715331987496 0.19955654102

# %%
print(np.mean(best_scores))
print(np.mean(predicted_scores))
# Out:
# 0.448535847451
# 0.191757079141
